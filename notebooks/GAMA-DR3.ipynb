# %%
# %matplotlib inline

from __future__ import print_function, division
import numpy as np
import sys, os
from astropy.table import Table
from astropy.io import fits
import fitsio
import matplotlib.pyplot as plt

# %%
cat = Table.read('/Users/roz18/Downloads/GAMA-DR3-SpecObj.fits')

# %%
print(len(cat))
# Out:
# 160026

# %%
cat
# Out:
# <Table masked=True length=160026>
#  CATAID ...
#         ...
#  int32  ...
# ------- ...
#    6802 ...
#    6806 ...
#    6808 ...
#    6810 ...
#    6813 ...
#    6816 ...
#    6820 ...
#    6821 ...
#    6826 ...
#     ... ...
# 8009007 ...
# 8009008 ...
# 8009009 ...
# 8009010 ...
# 8009011 ...
# 8009012 ...
# 8009013 ...
# 8009014 ...
# 8009015 ...
# 8009016 ...

# %%
plt.figure(figsize=(15, 8))
plt.plot(cat['RA'], cat['DEC'], '.', markersize=0.4, alpha=0.5)
plt.xlabel('RA')
plt.ylabel('DEC')
plt.title('GAMA DR3')
plt.show()

# %% [markdown]
# __Check for duplicates__

# %%
from __future__ import division, print_function
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import sys, os
home = os.path.expanduser("~")+'/'
sys.path.append(home+'git/Python/user_modules/')
import match_coord

# %%
n_duplicates, idx1, idx2 = match_coord.match_self(cat['RA'], cat['DEC'], search_radius=1., 
                                                  return_indices=True, plot_q=True)
print(n_duplicates, '{:.2f}%'.format(n_duplicates/len(cat)*100))
# Out:
# 4 objects with a nearby neighbor
# 4 0.00%
