# %%
# %matplotlib inline

from __future__ import print_function, division
import numpy as np
import sys, os
from astropy.table import Table
import fitsio
import matplotlib.pyplot as plt

# %%
cat = Table.read('/Users/roz18/Downloads/2mrs_v240/catalog/2mrs_1175_done.fits')

# %%
print(len(cat))
# Out:
# 43533

# %%
cat
# Out:
# <Table length=43533>
#       TMID           RA    ...         VSRC                   CATID
#       text          deg    ...         text                    text
#      str16        float32  ...        str19                   str28
# ---------------- --------- ... ------------------- ----------------------------
# 00424433+4116074  10.68471 ... 1991RC3.9.C...0000d MESSIER_031
# 00473313-2517196  11.88806 ... 2004AJ....128...16K NGC_0253
# 09553318+6903549 148.88826 ... 1991RC3.9.C...0000d MESSIER_081
# 13252775-4301073 201.36565 ... 1978PASP...90..237G NGC_5128
# 13052727-4928044 196.36366 ... 2004AJ....128...16K NGC_4945
# 01335090+3039357   23.4621 ... 1991RC3.9.C...0000d MESSIER_033
# 09555243+6940469 148.96846 ... 1991RC3.9.C...0000d MESSIER_082
# 03464851+6805459  56.70214 ... 1999PASP..111..438F IC_0342
# 13370091-2951567 204.25383 ... 2004AJ....128...16K MESSIER_083
#              ...       ... ...                 ...                          ...
# 20381882-0406569 309.57846 ... 20096dF...C...0000J g2038188-040657
# 20473231+2229276  311.8846 ... 20112MRS.FLWO.0000H 20473231+2229276
# 20530273+6624129 313.26117 ... 20112MRS.FLWO.0000H 20530273+6624129
# 21002390+0927135 315.09958 ... 20112MRS.JPH..0000H CGCG_400-018
# 21104224-4855014 317.67612 ... 20096dF...C...0000J g2110423-485502
# 22064989+2501234 331.70792 ... 20112MRS.FLWO.0000H A2204+2446
# 22564201-4812368 344.17505 ... 20096dF...C...0000J g2256420-481237
# 23241975+0126293 351.08228 ... 20112MRS.FLWO.0000H 23241975+0126293
# 23270825-4936242 351.78433 ... 1995AJ....110.1032M 2MASX_J23270825-4936242
# 23520287+2102068 358.01202 ... 20112MRS.FLWO.0000H 23520287+2102068

# %%
plt.figure(figsize=(15, 8))
plt.plot(cat['RA'], cat['DEC'], '.', markersize=0.8, alpha=0.5)
plt.xlabel('RA')
plt.ylabel('DEC')
plt.title('2MRS')
plt.show()

# %% [markdown]
# __Check for duplicates__

# %%
from __future__ import division, print_function
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import sys, os
home = os.path.expanduser("~")+'/'
sys.path.append(home+'git/Python/user_modules/')
import match_coord

# %%
n_duplicates, idx1, idx2 = match_coord.match_self(cat['RA'], cat['DEC'], search_radius=1., 
                                                  return_indices=True, plot_q=True)
print(n_duplicates, '{:.2f}%'.format(n_duplicates/len(cat)*100))
# Out:
# 0 objects with a nearby neighbor
# 0 0.00%
